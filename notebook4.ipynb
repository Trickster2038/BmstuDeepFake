# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sergey.astakhov\\Desktop\\BmstuDeepFake'

# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_json("../deep_fake_src/dfdc_dataframes/dataframe_compact_total_27_frame_10_lim100_offset0.json")
print('readed #1')
df1 = pd.read_json("../deep_fake_src/dfdc_dataframes/dataframe_compact_total_27_frame_10_lim100_offset100.json")
print('readed #2')
df2 = pd.read_json("../deep_fake_src/dfdc_dataframes/dataframe_compact_total_27_frame_10_lim100_offset200.json")
print('readed #3')
df3 = pd.read_json("../deep_fake_src/dfdc_dataframes/dataframe_compact_total_27_frame_10_lim100_offset300.json")
print('readed #4')
df4 = pd.read_json("../deep_fake_src/dfdc_dataframes/dataframe_compact_total_27_frame_10_lim100_offset400.json")
print('readed #5')
df5 = pd.read_json("../deep_fake_src/dfdc_dataframes/dataframe_compact_total_27_frame_10_lim100_offset500.json")
print('readed #6')
df6 = pd.read_json("../deep_fake_src/dfdc_dataframes/dataframe_compact_total_27_frame_10_lim100_offset600.json")
print('readed #7')
df7 = pd.read_json("../deep_fake_src/dfdc_dataframes/dataframe_compact_total_27_frame_10_lim100_offset700.json")
print('readed #8')
df8 = pd.read_json("../deep_fake_src/dfdc_dataframes/dataframe_compact_total_27_frame_10_lim100_offset800.json")
print('readed #9')

df = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8])

face = df.filter(like='face', axis=1).copy()

for col in face:
    name = str(col) + '_reversed'
    df[name] = face[str(col)].map(lambda x: 1.0 / max(1,x))

df = df.filter(regex='^(.(?!(var)))*$', axis=1).filter(regex='^(.(?!(noise_1)))*$', axis=1)

df.head()
# Out:
# readed #1
# readed #2
# readed #3
# readed #4
# readed #5
# readed #6
# readed #7
# readed #8
# readed #9
#    index        filename   fake  face_size_px  pt_48_std  pt_49_std  \
# 0      0  aajrvbynqc.mp4  False         51984  11.603861  15.950859
# 1      1  aajrvbynqc.mp4  False         50176  15.218397  18.602677
# 2      2  aajrvbynqc.mp4  False         48400  17.841354  19.709579
# 3      3  aajrvbynqc.mp4  False         50176  14.979666  18.559879
# 4      4  aajrvbynqc.mp4  False         51076  14.595270  19.162088
#
#    pt_50_std  pt_51_std  pt_52_std  pt_53_std  ...  pt_13_hist_noise_3  \
# 0  22.036234  19.959687  13.405562  12.777617  ...                30.0
# 1  20.166547  22.638240  15.031301  11.682786  ...                 9.0
# 2  22.040279  22.029932  15.643900  11.475191  ...                 4.0
# 3  21.796997  21.838523  15.232203  12.212530  ...                 3.0
# 4  21.454221  23.099652  15.149056  11.454065  ...                 5.0
#
#    pt_14_hist_noise_3  pt_15_hist_noise_3  pt_16_hist_noise_3  \
# 0                23.0                 9.0                18.0
# 1                10.0                 8.0                20.0
# 2                 7.0                 6.0                18.0
# 3                11.0                 9.0                14.0
# 4                11.0                 7.0                22.0
#
#    overall_face_hist_noise_3  face_size_px_reversed  \
# 0                   0.392428               0.000019
# 1                   0.408562               0.000020
# 2                   0.425620               0.000021
# 3                   0.412548               0.000020
# 4                   0.403321               0.000020
#
#    overall_face_std_reversed  overall_face_hist_std_reversed  \
# 0                   0.015754                        0.004667
# 1                   0.015523                        0.004635
# 2                   0.015374                        0.004661
# 3                   0.015353                        0.004538
# 4                   0.015287                        0.004425
#
#    overall_face_hist_noise_0.5_reversed  overall_face_hist_noise_3_reversed
# 0                                   1.0                                 1.0
# 1                                   1.0                                 1.0
# 2                                   1.0                                 1.0
# 3                                   1.0                                 1.0
# 4                                   1.0                                 1.0
#
# [5 rows x 281 columns]

# %%
df.shape
# Out:
# (9809, 281)

# %%
df_keys = pd.DataFrame(data=df[['filename', 'fake']], columns=["filename", "fake"])
df_keys_cnt = df_keys.groupby(["filename", "fake"])["filename"].count()
df_keys_cnt = pd.DataFrame(data=df_keys_cnt, columns=["filename", "cnt"])
df_keys_cnt["cnt"] = df_keys_cnt["filename"]
df_keys_cnt = df_keys_cnt.drop(columns=["filename"])
df_keys_cnt["_filename"] = df_keys_cnt.index
df_keys_cnt = df_keys_cnt.reset_index(drop=True)
df_keys_cnt["filename"] = df_keys_cnt["_filename"].map(lambda x: x[0])
df_keys_cnt["fake"] = df_keys_cnt["_filename"].map(lambda x: x[1])
# df_keys_cnt.columns = ["filename", "cnt"]
df_keys_cnt = df_keys_cnt.drop(columns=["_filename"])
df_keys_cnt.head()
# df_keys.head()
# Out:
#    cnt        filename   fake
# 0   11  aajrvbynqc.mp4  False
# 1   15  aasrzgbdpp.mp4  False
# 2   15  abplofmgwg.mp4  False
# 3   15  absytkidsf.mp4   True
# 4   15  abszlbwsaz.mp4   True

# %%
df_keys_cnt.shape
# Out:
# (793, 3)

# %%
df_keys_cnt = df_keys_cnt[df_keys_cnt["cnt"] > 8]
df_keys_cnt.shape
# Out:
# (661, 3)

# %%
df_keys_cnt = pd.concat([
    df_keys_cnt[df_keys_cnt.fake==True].sample(
        int(df_keys_cnt[df_keys_cnt.fake==False].shape[0]*1)), 
    df_keys_cnt[df_keys_cnt.fake==False]
])
df_keys_cnt.shape
# df_keys_cnt = df_keys_cnt.sample(200)
# Out:
# (256, 3)

# %%
# from notebook2
# TODO: smart import through file

features = ['overall_face_hist_noise_0.5_reversed',
 'pt_57_hist_noise_0.5',
 'pt_56_hist_noise_0.5',
 'pt_7_hist_noise_3',
 'overall_face_hist_noise_3',
 'pt_56_hist_noise_3',
 'overall_face_hist_std_reversed',
 'pt_58_hist_noise_3',
 'pt_39_hist_noise_3',
 'pt_58_hist_noise_0.5',
 'pt_20_hist_noise_0.5',
 'pt_19_hist_noise_0.5',
 'pt_39_std',
 'pt_57_std',
 'overall_face_hist_noise_3_reversed',
 'pt_57_hist_std',
 'overall_face_hist_noise_0.5',
 'pt_50_hist_noise_0.5',
 'pt_24_hist_noise_0.5',
 'pt_57_hist_noise_3',
 'pt_58_std',
 'overall_face_hist_std',
 'pt_8_hist_noise_3',
 'pt_58_hist_std',
 'overall_face_std_reversed',
 'face_size_px_reversed',
 'pt_45_hist_noise_3']
features
# Out:
# ['overall_face_hist_noise_0.5_reversed',
#  'pt_57_hist_noise_0.5',
#  'pt_56_hist_noise_0.5',
#  'pt_7_hist_noise_3',
#  'overall_face_hist_noise_3',
#  'pt_56_hist_noise_3',
#  'overall_face_hist_std_reversed',
#  'pt_58_hist_noise_3',
#  'pt_39_hist_noise_3',
#  'pt_58_hist_noise_0.5',
#  'pt_20_hist_noise_0.5',
#  'pt_19_hist_noise_0.5',
#  'pt_39_std',
#  'pt_57_std',
#  'overall_face_hist_noise_3_reversed',
#  'pt_57_hist_std',
#  'overall_face_hist_noise_0.5',
#  'pt_50_hist_noise_0.5',
#  'pt_24_hist_noise_0.5',
#  'pt_57_hist_noise_3',
#  'pt_58_std',
#  'overall_face_hist_std',
#  'pt_8_hist_noise_3',
#  'pt_58_hist_std',
#  'overall_face_std_reversed',
#  'face_size_px_reversed',
#  'pt_45_hist_noise_3']

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

keys_train, keys_test, _, _ = train_test_split( 
    df_keys_cnt, 
    df_keys_cnt,
    test_size=0.450, # ? reversed, because usually not refitting 1st-level model ?
    random_state=420)
keys_train = pd.DataFrame(keys_train)
keys_test = pd.DataFrame(keys_test)
keys_train.head()
# Out:
#      cnt        filename   fake
# 439   12  fswjeuiwks.mp4   True
# 397   14  fcjossnylc.mp4  False
# 451    9  fxlagyqpfc.mp4   True
# 635   15  hvizhucxwb.mp4   True
# 503   15  glamnffbfe.mp4  False

# %%
keys_test.head()
# Out:
#      cnt        filename   fake
# 666   15  iezaeaizzp.mp4  False
# 432   15  fqjdyomacd.mp4  False
# 491   15  giebymunak.mp4   True
# 351   15  emqiwrsihy.mp4  False
# 431   14  fqadxvyblp.mp4   True

# %%
df_merged_train = keys_train.merge(df, on='filename')
df_merged_train["fake"] = df_merged_train["fake_x"]
df_merged_train = df_merged_train.drop(columns=["index", "fake_x", "fake_y"])

df_merged_test = keys_test.merge(df, on='filename')
df_merged_test["fake"] = df_merged_test["fake_x"]
df_merged_test = df_merged_test.drop(columns=["index", "fake_x", "fake_y"])

df_merged_train.head()
# Out:
#    cnt        filename  face_size_px  pt_48_std  pt_49_std  pt_50_std  \
# 0   12  fswjeuiwks.mp4        179776   4.751915   7.144921   4.348077
# 1   12  fswjeuiwks.mp4        160000   4.295474   5.834916   4.195497
# 2   12  fswjeuiwks.mp4        193600   4.462014   4.377157   4.337695
# 3   12  fswjeuiwks.mp4        197136   4.521471   5.856748   4.410042
# 4   12  fswjeuiwks.mp4        188356   2.732965   5.914828   4.996148
#
#    pt_51_std  pt_52_std  pt_53_std  pt_54_std  ...  pt_14_hist_noise_3  \
# 0   2.708218   5.650216  10.255768   7.919216  ...            0.250000
# 1   5.683726   2.443926   3.291731   6.875696  ...            4.250000
# 2   3.206219   2.187516   3.004462   5.718787  ...            3.305785
# 3   1.348931   0.948489   4.709977   4.664652  ...            4.132231
# 4   2.439456   0.975932   2.196632   2.478588  ...            3.750000
#
#    pt_15_hist_noise_3  pt_16_hist_noise_3  overall_face_hist_noise_3  \
# 0            2.000000           10.000000                   0.045612
# 1            3.250000            3.250000                   0.059375
# 2            3.512397            5.371901                   0.039256
# 3            6.404959            6.611570                   0.040074
# 4            4.500000            7.250000                   0.041942
#
#    face_size_px_reversed  overall_face_std_reversed  \
# 0               0.000006                   0.042149
# 1               0.000006                   0.042095
# 2               0.000005                   0.040651
# 3               0.000005                   0.040790
# 4               0.000005                   0.041268
#
#    overall_face_hist_std_reversed  overall_face_hist_noise_0.5_reversed  \
# 0                        0.000632                                   1.0
# 1                        0.000816                                   1.0
# 2                        0.000476                                   1.0
# 3                        0.000404                                   1.0
# 4                        0.000467                                   1.0
#
#    overall_face_hist_noise_3_reversed  fake
# 0                                 1.0  True
# 1                                 1.0  True
# 2                                 1.0  True
# 3                                 1.0  True
# 4                                 1.0  True
#
# [5 rows x 281 columns]

# %%
df_merged_test.head()
# Out:
#    cnt        filename  face_size_px  pt_48_std  pt_49_std  pt_50_std  \
# 0   15  iezaeaizzp.mp4        107584  13.903857  17.369550  13.761114
# 1   15  iezaeaizzp.mp4        106276  13.387149  17.347858  13.565910
# 2   15  iezaeaizzp.mp4        107584  14.260708  17.245070  13.696645
# 3   15  iezaeaizzp.mp4        107584  14.485668  18.047949  14.245596
# 4   15  iezaeaizzp.mp4        106276  14.639383  18.169621  14.573150
#
#    pt_51_std  pt_52_std  pt_53_std  pt_54_std  ...  pt_14_hist_noise_3  \
# 0  17.930474  14.416362  18.066906  13.729552  ...           14.453125
# 1  18.245220  15.294551  17.720347  13.542756  ...           13.281250
# 2  18.169557  15.444739  18.062239  12.294700  ...           10.156250
# 3  19.132157  15.503342  18.916203  12.417648  ...            9.375000
# 4  19.478855  15.381936  18.542114  12.412978  ...           15.625000
#
#    pt_15_hist_noise_3  pt_16_hist_noise_3  overall_face_hist_noise_3  \
# 0           14.843750           12.890625                   0.126413
# 1           15.234375           14.453125                   0.131732
# 2           15.234375           15.234375                   0.132919
# 3           16.796875           16.015625                   0.132919
# 4           14.843750           14.453125                   0.135496
#
#    face_size_px_reversed  overall_face_std_reversed  \
# 0               0.000009                   0.028759
# 1               0.000009                   0.028387
# 2               0.000009                   0.028298
# 3               0.000009                   0.028158
# 4               0.000009                   0.028358
#
#    overall_face_hist_std_reversed  overall_face_hist_noise_0.5_reversed  \
# 0                        0.001133                                   1.0
# 1                        0.001164                                   1.0
# 2                        0.001134                                   1.0
# 3                        0.001155                                   1.0
# 4                        0.001166                                   1.0
#
#    overall_face_hist_noise_3_reversed   fake
# 0                                 1.0  False
# 1                                 1.0  False
# 2                                 1.0  False
# 3                                 1.0  False
# 4                                 1.0  False
#
# [5 rows x 281 columns]

# %%
df_merged_train.shape
# Out:
# (1959, 281)

# %%
df_merged_test.shape
# Out:
# (1650, 281)

# %%
X_train =  df_merged_train[features]
y_train = df_merged_train['fake']

X_test =  df_merged_test[features]
y_test = df_merged_test['fake']

pd.DataFrame(X_train).head()
# Out:
#    overall_face_hist_noise_0.5_reversed  pt_57_hist_noise_0.5  \
# 0                                   1.0              1.000000
# 1                                   1.0              0.500000
# 2                                   1.0              0.413223
# 3                                   1.0              0.413223
# 4                                   1.0              0.500000
#
#    pt_56_hist_noise_0.5  pt_7_hist_noise_3  overall_face_hist_noise_3  \
# 0              2.250000           0.750000                   0.045612
# 1              0.000000           0.750000                   0.059375
# 2              0.619835           0.619835                   0.039256
# 3              0.000000           0.413223                   0.040074
# 4              0.000000           0.750000                   0.041942
#
#    pt_56_hist_noise_3  overall_face_hist_std_reversed  pt_58_hist_noise_3  \
# 0            9.750000                        0.000632            2.250000
# 1            5.750000                        0.000816            5.750000
# 2            4.132231                        0.000476            5.991736
# 3            3.512397                        0.000404            3.512397
# 4            1.500000                        0.000467            3.500000
#
#    pt_39_hist_noise_3  pt_58_hist_noise_0.5  ...  pt_50_hist_noise_0.5  \
# 0            2.000000              0.000000  ...              0.250000
# 1            4.250000              0.000000  ...              0.750000
# 2            2.685950              0.826446  ...              0.826446
# 3            3.719008              0.413223  ...              0.619835
# 4            2.250000              0.000000  ...              0.250000
#
#    pt_24_hist_noise_0.5  pt_57_hist_noise_3  pt_58_std  overall_face_hist_std  \
# 0              0.250000            6.500000   8.496764            1581.050924
# 1              0.250000            5.500000   9.217684            1225.417936
# 2              0.413223            4.545455  10.269421            2098.781767
# 3              0.206612            4.132231   8.595006            2475.689919
# 4              0.000000            2.500000   7.152272            2141.957479
#
#    pt_8_hist_noise_3  pt_58_hist_std  overall_face_std_reversed  \
# 0           0.250000        5.126905                   0.042149
# 1           0.500000        5.359352                   0.042095
# 2           0.619835        5.365885                   0.040651
# 3           0.619835        6.329167                   0.040790
# 4           0.750000        5.334513                   0.041268
#
#    face_size_px_reversed  pt_45_hist_noise_3
# 0               0.000006            6.500000
# 1               0.000006            2.750000
# 2               0.000005            3.512397
# 3               0.000005            4.545455
# 4               0.000005            4.000000
#
# [5 rows x 27 columns]

# %%
from joblib import dump, load
# dont use random forest because of separate features anomalies
clf = load('knn.pkl')
# clf = load('logistic_regression.pkl')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
clf = clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)
print(classification_report(
        y_test, 
        y_pred, 
        target_names=['class "real"', 'class "fakes"'], 
        zero_division=np.nan)
     )
# Out:
#                precision    recall  f1-score   support
#
#  class "real"       0.60      0.78      0.68       824
# class "fakes"       0.68      0.48      0.56       826
#
#      accuracy                           0.63      1650
#     macro avg       0.64      0.63      0.62      1650
#  weighted avg       0.64      0.63      0.62      1650

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
y_pred_proba = clf.predict_proba(X_test)
y_pred_proba[:, 0]
# Out:
# array([1.        , 1.        , 1.        , ..., 0.5600785 , 0.25005905,
#        0.        ])

# %%
X_test
# Out:
#       overall_face_hist_noise_0.5_reversed  pt_57_hist_noise_0.5  \
# 0                                      1.0              3.906250
# 1                                      1.0              3.125000
# 2                                      1.0              3.515625
# 3                                      1.0              4.296875
# 4                                      1.0              5.468750
# ...                                    ...                   ...
# 1645                                   1.0              0.000000
# 1646                                   1.0              0.000000
# 1647                                   1.0              0.000000
# 1648                                   1.0              0.000000
# 1649                                   1.0              0.000000
#
#       pt_56_hist_noise_0.5  pt_7_hist_noise_3  overall_face_hist_noise_3  \
# 0                 5.078125           4.296875                   0.126413
# 1                 6.250000           4.687500                   0.131732
# 2                 3.906250           4.687500                   0.132919
# 3                 5.078125           3.125000                   0.132919
# 4                 3.906250           2.343750                   0.135496
# ...                    ...                ...                        ...
# 1645              0.000000           8.333333                   0.424611
# 1646              0.000000           0.000000                   0.414062
# 1647              0.000000           2.777778                   0.435569
# 1648              0.000000           5.555556                   0.432623
# 1649              0.000000           5.555556                   0.436629
#
#       pt_56_hist_noise_3  overall_face_hist_std_reversed  pt_58_hist_noise_3  \
# 0              20.312500                        0.001133           24.609375
# 1              23.046875                        0.001164           23.437500
# 2              21.484375                        0.001134           23.437500
# 3              23.046875                        0.001155           23.437500
# 4              21.093750                        0.001166           23.046875
# ...                  ...                             ...                 ...
# 1645           19.444444                        0.004450           27.777778
# 1646           17.187500                        0.004395           25.000000
# 1647           19.444444                        0.004782           22.222222
# 1648           22.222222                        0.004574           16.666667
# 1649           13.888889                        0.004760           11.111111
#
#       pt_39_hist_noise_3  pt_58_hist_noise_0.5  ...  pt_50_hist_noise_0.5  \
# 0              23.828125              5.859375  ...              5.468750
# 1              27.734375              5.078125  ...              4.687500
# 2              26.171875              3.515625  ...              5.078125
# 3              25.000000              1.953125  ...              5.078125
# 4              23.828125              3.125000  ...              5.468750
# ...                  ...                   ...  ...                   ...
# 1645           22.222222              0.000000  ...              0.000000
# 1646           15.625000              0.000000  ...              0.000000
# 1647           25.000000              0.000000  ...              0.000000
# 1648            8.333333              0.000000  ...              0.000000
# 1649           19.444444              0.000000  ...              0.000000
#
#       pt_24_hist_noise_0.5  pt_57_hist_noise_3  pt_58_std  \
# 0                 7.421875           23.046875  20.423806
# 1                 7.421875           20.312500  20.250684
# 2                 6.250000           21.093750  20.625923
# 3                 7.812500           20.312500  21.466984
# 4                 7.421875           22.265625  20.297566
# ...                    ...                 ...        ...
# 1645              0.000000           16.666667   9.174071
# 1646              0.000000           20.312500  11.930780
# 1647              0.000000           16.666667   5.802032
# 1648              0.000000           30.555556   5.839613
# 1649              0.000000           19.444444   3.459086
#
#       overall_face_hist_std  pt_8_hist_noise_3  pt_58_hist_std  \
# 0                882.262557           3.515625        2.100967
# 1                859.396370           4.296875        2.128673
# 2                881.542828           3.515625        2.048246
# 3                866.078938           4.296875        2.009742
# 4                857.857681           3.906250        2.076656
# ...                     ...                ...             ...
# 1645             224.698843           2.777778        0.548213
# 1646             227.532844           0.000000        0.810093
# 1647             209.112756           2.777778        0.640244
# 1648             218.621658           5.555556        0.615355
# 1649             210.101984           0.000000        0.741982
#
#       overall_face_std_reversed  face_size_px_reversed  pt_45_hist_noise_3
# 0                      0.028759               0.000009           23.437500
# 1                      0.028387               0.000009           29.687500
# 2                      0.028298               0.000009           30.859375
# 3                      0.028158               0.000009           29.687500
# 4                      0.028358               0.000009           29.296875
# ...                         ...                    ...                 ...
# 1645                   0.025801               0.000040           11.111111
# 1646                   0.026491               0.000039            7.812500
# 1647                   0.026454               0.000041            8.333333
# 1648                   0.026856               0.000040            5.555556
# 1649                   0.026346               0.000040            2.777778
#
# [1650 rows x 27 columns]

# %%
pd.DataFrame(y_pred, columns=["prediction"])
# Out:
#       prediction
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 1645       False
# 1646        True
# 1647       False
# 1648        True
# 1649        True
#
# [1650 rows x 1 columns]

# %%
df_merged_test_cp = df_merged_test.copy()

# %%
df_merged_test_cp["prediction"] = y_pred
dictt = {True: 1, False: 0}
df_merged_test_cp["prediction_proba"] = y_pred_proba[:, 0]
df_merged_test_cp["prediction_int"] = df_merged_test_cp["prediction"].map(lambda x: dictt[x])
df_merged_test_cp["prediction_match_int"] = (df_merged_test_cp["prediction"] == df_merged_test_cp["fake"])
df_merged_test_cp["prediction_match_int"] = df_merged_test_cp["prediction_match_int"].map(lambda x: dictt[x])

# %%
df_merged_test_cp
# Out:
#       cnt        filename  face_size_px  pt_48_std  pt_49_std  pt_50_std  \
# 0      15  iezaeaizzp.mp4        107584  13.903857  17.369550  13.761114
# 1      15  iezaeaizzp.mp4        106276  13.387149  17.347858  13.565910
# 2      15  iezaeaizzp.mp4        107584  14.260708  17.245070  13.696645
# 3      15  iezaeaizzp.mp4        107584  14.485668  18.047949  14.245596
# 4      15  iezaeaizzp.mp4        106276  14.639383  18.169621  14.573150
# ...   ...             ...           ...        ...        ...        ...
# 1645   14  ektpcycwsa.mp4         24964   3.541639   9.429195   8.176440
# 1646   14  ektpcycwsa.mp4         25600   5.799696  13.823799   8.907716
# 1647   14  ektpcycwsa.mp4         24336   5.128894  10.140068   9.641850
# 1648   14  ektpcycwsa.mp4         24964   5.101743  10.100727   7.531211
# 1649   14  ektpcycwsa.mp4         24964   4.872685   9.514244   4.787780
#
#       pt_51_std  pt_52_std  pt_53_std  pt_54_std  ...  face_size_px_reversed  \
# 0     17.930474  14.416362  18.066906  13.729552  ...               0.000009
# 1     18.245220  15.294551  17.720347  13.542756  ...               0.000009
# 2     18.169557  15.444739  18.062239  12.294700  ...               0.000009
# 3     19.132157  15.503342  18.916203  12.417648  ...               0.000009
# 4     19.478855  15.381936  18.542114  12.412978  ...               0.000009
# ...         ...        ...        ...        ...  ...                    ...
# 1645   9.534659   6.975929   3.862210   2.962731  ...               0.000040
# 1646   7.823851   6.053715   5.350872   3.935981  ...               0.000039
# 1647   9.179747   6.832430   4.708149   1.810463  ...               0.000041
# 1648   8.737778   5.705477   3.706434   1.635590  ...               0.000040
# 1649   9.125666   7.036062   3.120521   2.351123  ...               0.000040
#
#       overall_face_std_reversed  overall_face_hist_std_reversed  \
# 0                      0.028759                        0.001133
# 1                      0.028387                        0.001164
# 2                      0.028298                        0.001134
# 3                      0.028158                        0.001155
# 4                      0.028358                        0.001166
# ...                         ...                             ...
# 1645                   0.025801                        0.004450
# 1646                   0.026491                        0.004395
# 1647                   0.026454                        0.004782
# 1648                   0.026856                        0.004574
# 1649                   0.026346                        0.004760
#
#       overall_face_hist_noise_0.5_reversed  \
# 0                                      1.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
# ...                                    ...
# 1645                                   1.0
# 1646                                   1.0
# 1647                                   1.0
# 1648                                   1.0
# 1649                                   1.0
#
#       overall_face_hist_noise_3_reversed   fake  prediction  prediction_proba  \
# 0                                    1.0  False       False          1.000000
# 1                                    1.0  False       False          1.000000
# 2                                    1.0  False       False          1.000000
# 3                                    1.0  False       False          0.785142
# 4                                    1.0  False       False          1.000000
# ...                                  ...    ...         ...               ...
# 1645                                 1.0   True       False          0.784228
# 1646                                 1.0   True        True          0.237331
# 1647                                 1.0   True       False          0.560078
# 1648                                 1.0   True        True          0.250059
# 1649                                 1.0   True        True          0.000000
#
#       prediction_int  prediction_match_int
# 0                  0                     1
# 1                  0                     1
# 2                  0                     1
# 3                  0                     1
# 4                  0                     1
# ...              ...                   ...
# 1645               0                     0
# 1646               1                     1
# 1647               0                     0
# 1648               1                     1
# 1649               1                     1
#
# [1650 rows x 285 columns]

# %%
# TODO: why division by zero in hists in notebook 1/2 ???

# %%
df_sum = df_merged_test_cp.groupby(["filename", "fake"])["prediction_int"].mean() #sum
df_sum_proba = df_merged_test_cp.groupby(["filename", "fake"])["prediction_proba"].mean() #sum
f = lambda x: set(np.hstack(x.values))
df_concat_proba = df_merged_test_cp.groupby(["filename", "fake"]).agg({"prediction_proba": f})

df_cnt = df_merged_test_cp.groupby(["filename", "fake"])["filename"].count()
df_agg = pd.DataFrame(data=df_merged_test_cp[["filename", "fake"]], columns=["filename", "fake"])

df_cnt = pd.DataFrame(data=df_cnt)
df_cnt["cnt"] = df_cnt["filename"]

df_sum = pd.DataFrame(data=df_sum)
df_sum["sum"] = df_sum["prediction_int"]

df_sum_proba = pd.DataFrame(data=df_sum_proba)
df_sum_proba["sum_proba"] = df_sum_proba["prediction_proba"]

df_concat_proba = pd.DataFrame(data=df_concat_proba)
df_concat_proba["concat_proba"] = df_concat_proba["prediction_proba"]

df_agg = pd.DataFrame(data=pd.concat([df_cnt["cnt"], df_sum["sum"], df_sum_proba["sum_proba"], df_concat_proba["concat_proba"]], axis=1), columns=["cnt", "sum", "sum_proba", "concat_proba"])
# df_agg["sum"] = df_sum["sum"]
# df_agg["cnt"] = df_cnt["cnt"]

df_agg["filename"] = df_agg.index.map(lambda x: x[0])
df_agg["fake"] = df_agg.index.map(lambda x: x[1])

df_agg["avg"] = df_agg["sum"]
df_agg["avg_proba"] = df_agg["sum_proba"]
# df_agg["avg"] = df_agg["sum"] / df_agg["cnt"]
# df_agg["avg_proba"] = df_agg["sum_proba"] / df_agg["cnt"]

df_agg = df_agg.reset_index(drop=True)
df_agg.head()
# df_concat_proba.head()
# Out:
#    cnt       sum  sum_proba  \
# 0   15  0.000000   0.951406
# 1   15  0.933333   0.143147
# 2   15  1.000000   0.030307
# 3   15  0.266667   0.681909
# 4   14  0.071429   0.700723
#
#                                         concat_proba        filename   fake  \
# 0  {0.7170561004034739, 1.0, 0.7805907778213189, ...  aasrzgbdpp.mp4  False
# 1  {0.0, 0.2342092053623458, 0.23907961043082418,...  agtvzogidd.mp4   True
# 2     {0.20476096143277417, 0.0, 0.2498433432064876}  aivycazeqs.mp4   True
# 3  {0.7871955342155191, 0.7494732966125764, 0.776...  aiyvrupckg.mp4  False
# 4  {0.5428373575456192, 0.5110599012277867, 0.724...  amqvxdixtf.mp4  False
#
#         avg  avg_proba
# 0  0.000000   0.951406
# 1  0.933333   0.143147
# 2  1.000000   0.030307
# 3  0.266667   0.681909
# 4  0.071429   0.700723

# %%
df_agg.shape
# Out:
# (116, 8)

# %%
df_agg[df_agg["fake"] == True]["avg"].mean()
# Out:
# 0.47906040319833426

# %%
df_agg[df_agg["fake"] == False]["avg"].mean()
# Out:
# 0.22452279521245033

# %%
df_agg[df_agg["fake"] == True]["avg_proba"].mean()
# Out:
# 0.5166874699281909

# %%
df_agg[df_agg["fake"] == False]["avg_proba"].mean()
# Out:
# 0.7429748646398102

# %%
df_agg.shape
# Out:
# (116, 8)

# %%
# p = pd.DataFrame(pd.concat([df_agg["avg"], df_agg["avg_proba"]], axis=1))
# p

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split( 
    # pd.DataFrame(df_agg["avg"]), 
    # pd.DataFrame(df_agg["avg_proba"]), 
    # df_agg["concat_proba"][:7],
    pd.DataFrame(pd.concat([df_agg["avg"], df_agg["avg_proba"]], axis=1)), 
    df_agg["fake"],
    test_size=0.55, # or will be overfitted
    random_state=420)

# %%
X_train2.shape
# Out:
# (52, 2)

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import SGDClassifier

clf2 = LogisticRegression(
        max_iter=15000, 
        # penalty=None,
        class_weight='balanced',
        solver='liblinear',
        # tol=1e-6
    )
# clf2 = SGDClassifier()
# clf2 = RandomForestClassifier(max_depth=7, random_state=42)
# clf2 = SVC(gamma='auto')
# clf2 = KNeighborsClassifier(n_neighbors=2, weights='distance')
clf2.fit(X_train2, y_train2)
y_pred2 = clf2.predict(X_test2)

# %%
print(classification_report(
        y_test2, 
        y_pred2, 
        target_names=['class "real"', 'class "fakes"'], 
        zero_division=np.nan)
     )
# Out:
#                precision    recall  f1-score   support
#
#  class "real"       0.74      0.74      0.74        34
# class "fakes"       0.70      0.70      0.70        30
#
#      accuracy                           0.72        64
#     macro avg       0.72      0.72      0.72        64
#  weighted avg       0.72      0.72      0.72        64
